# %%
import pandas as pd

# %%
df = pd.read_csv('../data/merged_output.csv', nrows=10_000)

# %%
df.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://garage-pirenne.be/index.php?option=com_...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#                                         original_url  url_type  url_len  \
# 0                                   br-icloud.com.br         2       16
# 1                mp3raid.com/music/krizz_kaliko.html         0       35
# 2                    bopsecrets.org/rexroth/cr/1.htm         0       31
# 3  http://www.garage-pirenne.be/index.php?option=...         1       77
# 4  http://adventure-nicaragua.net/index.php?optio...         1      228
#
#                 pri_domain  letters_count  digits_count  special_chars_count  \
# 0         br-icloud.com.br             13             0                    3
# 1              mp3raid.com             29             1                    5
# 2           bopsecrets.org             25             1                    5
# 3        garage-pirenne.be             60             7                   17
# 4  adventure-nicaragua.net            199            22                   14
#
#    ...          root_domain  \
# 0  ...            br-icloud
# 1  ...              mp3raid
# 2  ...           bopsecrets
# 3  ...       garage-pirenne
# 4  ...  adventure-nicaragua
#
#                                       original_url.1  \
# 0                            http://br-icloud.com.br
# 1         http://mp3raid.com/music/krizz_kaliko.html
# 2             http://bopsecrets.org/rexroth/cr/1.htm
# 3  http://www.garage-pirenne.be/index.php?option=...
# 4  http://adventure-nicaragua.net/index.php?optio...
#
#                                            final_url  \
# 0                           http://br-icloud.com.br/
# 1         http://mp3raid.com/music/krizz_kaliko.html
# 2            https://bopsecrets.org/rexroth/cr/1.htm
# 3  http://www.garage-pirenne.be/index.php?option=...
# 4  http://adventure-nicaragua.net/index.php?optio...
#
#                                       redirect_chain redirect_count  \
# 0                                                NaN              0
# 1                                                NaN              0
# 2  [{"url": "http://bopsecrets.org/rexroth/cr/1.h...              1
# 3                                                NaN              0
# 4                                                NaN              0
#
#                                        head_elements timeout has_meta_refresh  \
# 0                                                NaN   False            False
# 1                                                NaN   False            False
# 2  [{'tag': 'meta', 'attributes': {'http-equiv': ...   False            False
# 3                                                NaN   False            False
# 4                                                NaN   False             True
#
#                                     meta_refresh_url  duration_sec
# 0                                                NaN          4.55
# 1                                                NaN          2.78
# 2                                                NaN          6.41
# 3                                                NaN          4.71
# 4  http://adventure-nicaragua.net/index.php?optio...          4.51
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           10000 non-null  int64
#  1   url                  10000 non-null  object
#  2   type                 10000 non-null  object
#  3   original_url         10000 non-null  object
#  4   url_type             10000 non-null  int64
#  5   url_len              10000 non-null  int64
#  6   pri_domain           10000 non-null  object
#  7   letters_count        10000 non-null  int64
#  8   digits_count         10000 non-null  int64
#  9   special_chars_count  10000 non-null  int64
#  10  shortened            10000 non-null  int64
#  11  is_domain_in_url     10000 non-null  int64
#  12  secure_http          10000 non-null  int64
#  13  have_ip              10000 non-null  int64
#  14  url_region           10000 non-null  object
#  15  root_domain          9995 non-null   object
#  16  original_url.1       10000 non-null  object
#  17  final_url            7102 non-null   object
#  18  redirect_chain       5761 non-null   object
#  19  redirect_count       10000 non-null  int64
#  20  head_elements        6555 non-null   object
#  21  timeout              10000 non-null  bool
#  22  has_meta_refresh     10000 non-null  bool
#  23  meta_refresh_url     70 non-null     object
#  24  duration_sec         10000 non-null  float64
# dtypes: bool(2), float64(1), int64(11), object(11)
# memory usage: 1.8+ MB

# %%
df['type'].unique()
# Out:
# array(['phishing', 'benign', 'defacement', 'malware'], dtype=object)

# %%
# 目標件数
target_count = 10_000

# ラベルごとのデータ保存用
collected = {
    'phishing': [],
    'benign': [],
    'defacement': [],
    'malware': []
}

# 各ラベルのカウント
counts = {key: 0 for key in collected}

# chunkごとに読み込む
chunksize = 10_000
for chunk in pd.read_csv('../data/merged_output.csv', chunksize=chunksize):
    for label in collected:
        if counts[label] < target_count:
            # このラベルのデータをフィルタリング
            subset = chunk[chunk['type'] == label]
            remaining = target_count - counts[label]
            if not subset.empty:
                # ランダムにサンプルを抽出
                sampled = subset.sample(n=min(remaining, len(subset)), random_state=42)
                collected[label].append(sampled)
                counts[label] += len(sampled)

    # すべて収集できたら終了
    if all(count >= target_count for count in counts.values()):
        break

# 最終的にまとめる
balanced_df = pd.concat([pd.concat(collected[label]) for label in collected], ignore_index=True)

# 結果確認
print(balanced_df['type'].value_counts())
# Out:
# type
# phishing      10000
# benign        10000
# defacement    10000
# malware       10000
# Name: count, dtype: int64

# %%
balanced_df.to_csv('../data/balanced_random_40k_test2.csv', index=False)

# %%
balanced_df.head()
# Out:
#    Unnamed: 0                          url      type  \
# 0        1591          smolmaw5.beget.tech  phishing
# 1        3772          helps-instagram.com  phishing
# 2        1007    contatocliente-sac.com.br  phishing
# 3        9761           domowe.star-kom.eu  phishing
# 4        4559  yellow-directory-canada.com  phishing
#
#                   original_url  url_type  url_len  \
# 0          smolmaw5.beget.tech         2       19
# 1          helps-instagram.com         2       19
# 2    contatocliente-sac.com.br         2       25
# 3           domowe.star-kom.eu         2       18
# 4  yellow-directory-canada.com         2       27
#
#                     pri_domain  letters_count  digits_count  \
# 0          smolmaw5.beget.tech             16             1
# 1          helps-instagram.com             17             0
# 2    contatocliente-sac.com.br             22             0
# 3           domowe.star-kom.eu             15             0
# 4  yellow-directory-canada.com             24             0
#
#    special_chars_count  ...              root_domain  \
# 0                    2  ...                    beget
# 1                    2  ...          helps-instagram
# 2                    3  ...       contatocliente-sac
# 3                    3  ...                 star-kom
# 4                    3  ...  yellow-directory-canada
#
#                        original_url.1                    final_url  \
# 0          http://smolmaw5.beget.tech  http://smolmaw5.beget.tech/
# 1          http://helps-instagram.com                          NaN
# 2    http://contatocliente-sac.com.br                          NaN
# 3           http://domowe.star-kom.eu                          NaN
# 4  http://yellow-directory-canada.com                          NaN
#
#   redirect_chain redirect_count  \
# 0            NaN              0
# 1            NaN              0
# 2            NaN              0
# 3            NaN              0
# 4            NaN              0
#
#                                        head_elements timeout has_meta_refresh  \
# 0  [{'tag': 'meta', 'attributes': {'name': 'viewp...   False            False
# 1                                                NaN   False            False
# 2                                                NaN   False            False
# 3                                                NaN   False            False
# 4                                                NaN   False            False
#
#   meta_refresh_url  duration_sec
# 0              NaN          6.67
# 1              NaN          3.44
# 2              NaN          4.27
# 3              NaN          2.15
# 4              NaN          2.43
#
# [5 rows x 25 columns]
